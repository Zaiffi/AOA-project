# %% [markdown]
# <a href="https://colab.research.google.com/github/Zaiffi/AOA-project/blob/main/Huzaifa_53939.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
fruit_list= ["Apple","Grapes","Banana"]
print(fruit_list)
print(type(fruit_list))
fruit_list
# Out:
# ['Apple', 'Grapes', 'Banana']
# <class 'list'>
# ['Apple', 'Grapes', 'Banana']

# %%
fruit_list.append("Orange")
print(fruit_list)
# Out:
# ['Apple', 'Grapes', 'Banana', 'Orange', 'Orange', 'Orange']

# %%
fruit_list.clear()
print(fruit_list)
# Out:
# []

# %%
fruit_list.insert(1,"Apple")
print(fruit_list)
# Out:
# ['Apple', 'Apple']

# %%
fruit_list.insert(2,"Grapes")
print(fruit_list)
# Out:
# ['Apple', 'Apple', 'Grapes']

# %%
fruit_list.copy()
# Out:
# ['Apple', 'Apple', 'Grapes']

# %%
fruit_list.count("Apple")
# Out:
# 2

# %%
fruit_list.extend("Apple")

# %%
fruit_list.index("Apple")
print(fruit_list)
# Out:
# ['Apple', 'Apple', 'Grapes', 'A', 'p', 'p', 'l', 'e']

# %%
fruit_list.pop(1)
# Out:
# 'Apple'

# %%
print(fruit_list)
# Out:
# ['Grapes', 'A', 'p', 'p', 'l', 'e']

# %%
fruit_list.reverse()

# %%
print(fruit_list)
# Out:
# ['e', 'l', 'p', 'p', 'A', 'Grapes']

# %%
fruit_list.sort()

# %%
print(fruit_list)
# Out:
# ['A', 'Grapes', 'e', 'l', 'p', 'p']

# %%
len(fruit_list)
# Out:
# 6
